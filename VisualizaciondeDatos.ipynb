# %% [markdown]
# Actividad - Visualización
#
#
# *  Nombre: José Eduardo Díaz Maldonado
# *  Matrícula: A01735676

# %% [markdown]
# Carga las librerías necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/SemanaTec/Repositorio1/
# Out:
# /gdrive/MyDrive/SemanaTec/Repositorio1

# %% [markdown]
# Carga el conjunto de datos al ambiente de Google Colab y muestra los primeros 6 renglones

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e5ab5b02-eabe-43ee-abba-a84414ef3998" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5ab5b02-eabe-43ee-abba-a84414ef3998">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bestsellers with categories.csv to bestsellers with categories (1).csv
# User uploaded file "bestsellers with categories.csv" with length 51161 bytes

# %%
df = pd.read_csv('bestsellers with categories.csv')
df.head(6)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5       George R. R. Martin          4.4    12643     11  2011      Fiction

# %% [markdown]
# Crea una tabla resumen con las estadísticas generales de las variables numéricas

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
import seaborn as sns

sns.set()

# %% [markdown]
# ¿Cuál es el género con más publicaciones? Muéstralo en un gráfico

# %%
fig = plt.figure(figsize=(6,4))

sns.countplot(data=df, x = 'Genre')

plt.title('Género con más publicaciones')
plt.xlabel('Género')
plt.ylabel('Publicaciones')
# Out:
# Text(0, 0.5, 'Publicaciones')

# %% [markdown]
# ¿Cuántos libros del top 50 se publicaron por género en cada año? ¿Hay algún año donde hubo más libros de ficción en el top 50?. Muéstralo en un gráfico

# %%
sns.countplot(data=df, x='Year', hue='Genre')
plt.title('Libros publicados por género en cada año')
plt.xlabel('Años')
plt.ylabel('Publicaciones')
# Out:
# Text(0, 0.5, 'Publicaciones')

# %% [markdown]
# ¿Cómo se distribuye la variable Review? Muéstra el histografa

# %%
sns.histplot(data=df, x='Reviews')

plt.title('Distribución de Reviews')
# Out:
# Text(0.5, 1.0, 'Distribución de Reviews')

# %% [markdown]
# Ahora muéstralo en un gráfico de caja y bigote

# %%
fig = plt.figure(figsize=(9, 6))

sns.boxplot(data=df, x='Reviews')

plt.title('Boxplot Reviews')
# Out:
# Text(0.5, 1.0, 'Boxplot Reviews')

# %% [markdown]
# ¿Cómo se compara la evaluación del libro por género? ¿Qué genero es mejor evaluado por los lectores? Muéstralo en un solo gráfico de caja y bigote

# %%
fig = plt.figure(figsize=(7,5))

sns.boxplot(data=df, x='User Rating', y = 'Genre')

plt.title('Boxplots de las evaluaciones de libros por género')
# Out:
# Text(0.5, 1.0, 'Boxplots de las evaluaciones de libros por género')

# %% [markdown]
# ¿Cuál es la relación entre el número de reseñas y precios? Muéstralo en un gráfico de dispersión

# %%
fig = plt.figure(figsize=(6, 4))

# Gráfico scatterplot.
sns.scatterplot(data=df, x ='Price', y='Reviews', hue='Genre')

# Ejes y título. Colocamos la etiqueta correcta de acuerdo a la orientación.
plt.title('Relación entre el número de reseñas y precios')
plt.xlabel('Precios')
plt.ylabel('Reseñas')
# Out:
# Text(0, 0.5, 'Reseñas')

# %% [markdown]
# De la pregunta anterior, ¿Influye algo el año de publicación? ¿Cuál es la relación entre el número de reseñas, el precio y el año de publicación?
#
# IMPORTANTE: Selecciona una paleta de colores adecuada

# %%
selec = df[['Price','Reviews','Year']]
iris_corr = selec.corr()
sns.heatmap(data=iris_corr)

# %% [markdown]
# ¿Cuál es la correlación entre las variables numéricas ? Muéstralo en un gráfico. La variable año, a pesar de ser numérica, la vamos a considerar como cualitativa, así que la eliminaremos del análisis

# %%
selected = df[['Price','Reviews','User Rating','Genre']]

# %%
sns.pairplot(data=selected, hue='Genre')

# %%
iris_corr = selected.corr()
sns.heatmap(data=iris_corr)

# %% [markdown]
# ¿Cuáles variables tiene una fuerte relación positiva entre sí y cuáles tienen una fuerte relación negativa? (Esta pregunta no es de código) Responde la pregunta en la siguiente celda de texto.

# %% [markdown]
# *- Las variables que tienen una relación positiva son entre ellas misma por ejemplo precio con precio, mientras que las relaciones negativas son al relacionarla con otra variable.*
#
# *- La que menos se relaciona negativamente es la relación entre las reviews y user rating.*

# %% [markdown]
# Haz una gráfica donde podemos comparar la relación entre las tres variables númericas (User Rating, Reviews y Price) y que, además, podamos ver el efecto del libro. La Variable año, a pesar de ser numérica, la vamos a considerar cualitativa, así que la eliminaremos del análisis

# %%
sns.pairplot(data=selected, hue='Genre')
